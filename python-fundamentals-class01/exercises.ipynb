# %% [markdown]
# # Exercise 1

# %%
name = input ("Write your name: ")
age = input ("Write your age: ")
print ("Hello " + name + ", you are " + age + " years old.")
# Out:
# Hola Juan, tienes 19 años.

# %% [markdown]
# # Exercise 2

# %%
numero1 = int(input("Escribe el primer número: "))
numero2 = int(input("Escribe el segundo número: "))
suma = numero1 + numero2
resta = numero1 - numero2
multiplicacion = numero1 * numero2
division = numero1 / numero2
print("La suma es: " + str(suma))
print("La resta es: " + str(resta))
print("La multiplicación es: " + str(multiplicacion))
print("La división es: " + str(division))
# Out:
# La suma es: 4
# La resta es: 0
# La multiplicación es: 4
# La división es: 1.0

# %% [markdown]
# # exercise 3

# %%
numero = int(input("Escribe un número: "))
if numero % 2 == 0:
    print("El número es par.")
else:    print("El número es impar.")
# Out:
# El número es par.

# %% [markdown]
# # exersice 4

# %%
producto = input("Ingresa el nombre del producto: ")
precio = float(input("Ingresa el precio del producto: "))
cantidad = int(input("Ingresa la cantidad del producto; "))

total = precio * cantidad 

print( "El total que debes pagar es: " + str(total))
# Out:
# El total que debes pagar es: 36000.0

# %% [markdown]
# # Exercise 5

# %%
name = input ("Write your name: ")

def greet(name):
    print("Hello, " + name)

greet(name)
# Out:
# Hello, Juan
