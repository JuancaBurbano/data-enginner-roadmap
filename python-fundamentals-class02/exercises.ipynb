# %% [markdown]
# # Excercise 1

# %%
age = input ("How old are you? ")
age = int(age)

if age >= 18:
    print ("You are older than 18.")
else:    print ("You are younger than 18.")
# Out:
# The kernel failed to start as the Python Environment 'Python 3.9.6' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.
